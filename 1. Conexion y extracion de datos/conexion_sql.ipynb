# %%
import pyodbc

try:

    conn = pyodbc.connect(

        'DRIVER={ODBC Driver 17 for SQL Server};'
        'SERVER=DESKTOP-UDI71R1\\SQLEXPRESS;'
        'DATABASE=HotelDB;'
        'Trusted_Connection=yes;'

    )

    print("✅ Conexión exitosa a SQL Server")

except Exception as e:

    print("❌ Error de conexión")
    print(e)
